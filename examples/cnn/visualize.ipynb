# %%
import numpy as np
import matplotlib.pyplot as plt
import jax.numpy as jnp
import jax
import sys
sys.path.append('../')
from visualize_optimization import plot_runs
jax.config.update("jax_enable_x64", True)
plt.rcParams['text.usetex'] = True

# %%
# Rand init and ideal edge-detection init
run_names = ["run_data/ed-init.csv"]
baseline = [0.4229]

plot_runs(run_names, ylabel="MSE", save_path="cnn-loss-vs-iter.pdf", method="min", window_size=1, ylog_scale=False, cmp_final_x=20, markevery=3)
# Out:
# run_data/ed-init.csv best run name: gallant-leaf-98 - train_loss, loss ~= 0.029683450283261026
